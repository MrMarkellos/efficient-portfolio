# %%
import pandas as pd
import yfinance as yf

# %%
start = "2020-02-04"
end = "2025-02-04"

# %%
symbol = [ "LCWD.L", "LYTNOW.SW", "ETH-USD", "TLT", "GIST.SW","GC=F", "O" ]

# %%
df = yf.download(symbol, start ,end)
df
# Out:
# [*********************100%%**********************]  7 of 7 completed
#            Adj Close                                                       \
#              ETH-USD      GC=F GIST.SW  LCWD.L LYTNOW.SW       O      TLT
# Date
# 2020-02-04  189.2506 1550.4000  9.7281 11.7240  374.3500 59.4838 126.1237
# 2020-02-05  204.2302 1557.8000  9.7339 11.8090  383.2500 59.6205 124.7446
# 2020-02-06  212.3391 1565.1000  9.7416 11.8700  380.5000 60.1142 125.3068
# 2020-02-07  222.7261 1568.6000  9.7877 11.8290  382.4000 60.3876 126.8703
# 2020-02-08  223.1465       NaN     NaN     NaN       NaN     NaN      NaN
# ...              ...       ...     ...     ...       ...     ...      ...
# 2025-01-30 3247.7800 2823.0000  9.8452 20.3750  894.0000 54.0575  88.0259
# 2025-01-31 3298.2651 2812.5000  9.8508 20.4800  910.9000 54.3760  87.4480
# 2025-02-01 3118.3286       NaN     NaN     NaN       NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN     NaN     NaN       NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999  9.9112 20.1300  883.0000 54.4900  88.1600
#
#                Close                    ...      Open                   \
#              ETH-USD      GC=F GIST.SW  ... LYTNOW.SW       O      TLT
# Date                                    ...
# 2020-02-04  189.2506 1550.4000 10.1300  ...  374.3500 75.6589 143.9900
# 2020-02-05  204.2302 1557.8000 10.1360  ...  377.7500 75.4651 142.3000
# 2020-02-06  212.3391 1565.1000 10.1440  ...  383.2500 76.1822 142.1800
# 2020-02-07  222.7261 1568.6000 10.1920  ...  382.4000 76.9767 144.2200
# 2020-02-08  223.1465       NaN     NaN  ...       NaN     NaN      NaN
# ...              ...       ...     ...  ...       ...     ...      ...
# 2025-01-30 3247.7800 2823.0000  9.8452  ...  906.3000 54.7000  88.4100
# 2025-01-31 3298.2651 2812.5000  9.8508  ...  910.9000 54.0900  88.3800
# 2025-02-01 3118.3286       NaN     NaN  ...       NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN     NaN  ...       NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999  9.9112  ...  875.4000 53.9000  88.5800
#
#                  Volume                                             \
#                 ETH-USD       GC=F   GIST.SW      LCWD.L LYTNOW.SW
# Date
# 2020-02-04  11714191695   978.0000    0.0000  12695.0000  105.0000
# 2020-02-05  14865434435  1305.0000    0.0000  32971.0000  370.0000
# 2020-02-06  16425589683   110.0000    0.0000    888.0000   28.0000
# 2020-02-07  16673443564   431.0000 2306.0000   6196.0000    1.0000
# 2020-02-08  16741203125        NaN       NaN         NaN       NaN
# ...                 ...        ...       ...         ...       ...
# 2025-01-30  19958405782 40141.0000    0.0000 138736.0000   18.0000
# 2025-01-31  30128115902  3443.0000    0.0000 462360.0000   27.0000
# 2025-02-01  19917507079        NaN       NaN         NaN       NaN
# 2025-02-02  42060930305        NaN       NaN         NaN       NaN
# 2025-02-03  92453553253  2649.0000    0.0000 237098.0000  272.0000
#
#
#                       O           TLT
# Date
# 2020-02-04 1291754.0000 11388300.0000
# 2020-02-05 1843874.0000 10782600.0000
# 2020-02-06 1047686.0000  6683100.0000
# 2020-02-07 1204034.0000 11374800.0000
# 2020-02-08          NaN           NaN
# ...                 ...           ...
# 2025-01-30 4277800.0000 25094900.0000
# 2025-01-31 6777500.0000 48812500.0000
# 2025-02-01          NaN           NaN
# 2025-02-02          NaN           NaN
# 2025-02-03 4324200.0000 70657200.0000
#
# [1827 rows x 42 columns]

# %%
df.to_csv("multi_assets.csv")

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")
# Out:
# C:\Users\marke\AppData\Local\Temp\ipykernel_12548\3115518178.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
pd.read_csv ("multi_assets.csv", header = [0,1], index_col = 0, parse_dates =[0])
# Out:
#            Adj Close                                                       \
#              ETH-USD      GC=F GIST.SW  LCWD.L LYTNOW.SW       O      TLT
# Date
# 2020-02-04  189.2506 1550.4000  9.7281 11.7240  374.3500 59.4838 126.1237
# 2020-02-05  204.2302 1557.8000  9.7339 11.8090  383.2500 59.6205 124.7446
# 2020-02-06  212.3391 1565.1000  9.7416 11.8700  380.5000 60.1142 125.3068
# 2020-02-07  222.7261 1568.6000  9.7877 11.8290  382.4000 60.3876 126.8703
# 2020-02-08  223.1465       NaN     NaN     NaN       NaN     NaN      NaN
# ...              ...       ...     ...     ...       ...     ...      ...
# 2025-01-30 3247.7800 2823.0000  9.8452 20.3750  894.0000 54.0575  88.0259
# 2025-01-31 3298.2651 2812.5000  9.8508 20.4800  910.9000 54.3760  87.4480
# 2025-02-01 3118.3286       NaN     NaN     NaN       NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN     NaN     NaN       NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999  9.9112 20.1300  883.0000 54.4900  88.1600
#
#                Close                    ...      Open                   \
#              ETH-USD      GC=F GIST.SW  ... LYTNOW.SW       O      TLT
# Date                                    ...
# 2020-02-04  189.2506 1550.4000 10.1300  ...  374.3500 75.6589 143.9900
# 2020-02-05  204.2302 1557.8000 10.1360  ...  377.7500 75.4651 142.3000
# 2020-02-06  212.3391 1565.1000 10.1440  ...  383.2500 76.1822 142.1800
# 2020-02-07  222.7261 1568.6000 10.1920  ...  382.4000 76.9767 144.2200
# 2020-02-08  223.1465       NaN     NaN  ...       NaN     NaN      NaN
# ...              ...       ...     ...  ...       ...     ...      ...
# 2025-01-30 3247.7800 2823.0000  9.8452  ...  906.3000 54.7000  88.4100
# 2025-01-31 3298.2651 2812.5000  9.8508  ...  910.9000 54.0900  88.3800
# 2025-02-01 3118.3286       NaN     NaN  ...       NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN     NaN  ...       NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999  9.9112  ...  875.4000 53.9000  88.5800
#
#                  Volume                                             \
#                 ETH-USD       GC=F   GIST.SW      LCWD.L LYTNOW.SW
# Date
# 2020-02-04  11714191695   978.0000    0.0000  12695.0000  105.0000
# 2020-02-05  14865434435  1305.0000    0.0000  32971.0000  370.0000
# 2020-02-06  16425589683   110.0000    0.0000    888.0000   28.0000
# 2020-02-07  16673443564   431.0000 2306.0000   6196.0000    1.0000
# 2020-02-08  16741203125        NaN       NaN         NaN       NaN
# ...                 ...        ...       ...         ...       ...
# 2025-01-30  19958405782 40141.0000    0.0000 138736.0000   18.0000
# 2025-01-31  30128115902  3443.0000    0.0000 462360.0000   27.0000
# 2025-02-01  19917507079        NaN       NaN         NaN       NaN
# 2025-02-02  42060930305        NaN       NaN         NaN       NaN
# 2025-02-03  92453553253  2649.0000    0.0000 237098.0000  272.0000
#
#
#                       O           TLT
# Date
# 2020-02-04 1291754.0000 11388300.0000
# 2020-02-05 1843874.0000 10782600.0000
# 2020-02-06 1047686.0000  6683100.0000
# 2020-02-07 1204034.0000 11374800.0000
# 2020-02-08          NaN           NaN
# ...                 ...           ...
# 2025-01-30 4277800.0000 25094900.0000
# 2025-01-31 6777500.0000 48812500.0000
# 2025-02-01          NaN           NaN
# 2025-02-02          NaN           NaN
# 2025-02-03 4324200.0000 70657200.0000
#
# [1827 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1827 entries, 2020-02-04 to 2025-02-03
# Freq: D
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Adj Close, ETH-USD)    1827 non-null   float64
#  1   (Adj Close, GC=F)       1259 non-null   float64
#  2   (Adj Close, GIST.SW)    1261 non-null   float64
#  3   (Adj Close, LCWD.L)     1262 non-null   float64
#  4   (Adj Close, LYTNOW.SW)  1261 non-null   float64
#  5   (Adj Close, O)          1257 non-null   float64
#  6   (Adj Close, TLT)        1257 non-null   float64
#  7   (Close, ETH-USD)        1827 non-null   float64
#  8   (Close, GC=F)           1259 non-null   float64
#  9   (Close, GIST.SW)        1261 non-null   float64
#  10  (Close, LCWD.L)         1262 non-null   float64
#  11  (Close, LYTNOW.SW)      1261 non-null   float64
#  12  (Close, O)              1257 non-null   float64
#  13  (Close, TLT)            1257 non-null   float64
#  14  (High, ETH-USD)         1827 non-null   float64
#  15  (High, GC=F)            1259 non-null   float64
#  16  (High, GIST.SW)         1261 non-null   float64
#  17  (High, LCWD.L)          1262 non-null   float64
#  18  (High, LYTNOW.SW)       1261 non-null   float64
#  19  (High, O)               1257 non-null   float64
#  20  (High, TLT)             1257 non-null   float64
#  21  (Low, ETH-USD)          1827 non-null   float64
#  22  (Low, GC=F)             1259 non-null   float64
#  23  (Low, GIST.SW)          1261 non-null   float64
#  24  (Low, LCWD.L)           1262 non-null   float64
#  25  (Low, LYTNOW.SW)        1261 non-null   float64
#  26  (Low, O)                1257 non-null   float64
#  27  (Low, TLT)              1257 non-null   float64
#  28  (Open, ETH-USD)         1827 non-null   float64
#  29  (Open, GC=F)            1259 non-null   float64
#  30  (Open, GIST.SW)         1261 non-null   float64
#  31  (Open, LCWD.L)          1262 non-null   float64
#  32  (Open, LYTNOW.SW)       1261 non-null   float64
#  33  (Open, O)               1257 non-null   float64
#  34  (Open, TLT)             1257 non-null   float64
#  35  (Volume, ETH-USD)       1827 non-null   int64
#  36  (Volume, GC=F)          1259 non-null   float64
#  37  (Volume, GIST.SW)       1261 non-null   float64
#  38  (Volume, LCWD.L)        1262 non-null   float64
#  39  (Volume, LYTNOW.SW)     1261 non-null   float64
#  40  (Volume, O)             1257 non-null   float64
#  41  (Volume, TLT)           1257 non-null   float64
# dtypes: float64(41), int64(1)
# memory usage: 613.8 KB

# %%
df.Close
# Out:
#              ETH-USD      GC=F  GIST.SW  LCWD.L  LYTNOW.SW       O      TLT
# Date
# 2020-02-04  189.2506 1550.4000  10.1300 11.7240   374.3500 75.8915 143.5800
# 2020-02-05  204.2302 1557.8000  10.1360 11.8090   383.2500 76.0659 142.0100
# 2020-02-06  212.3391 1565.1000  10.1440 11.8700   380.5000 76.6957 142.6500
# 2020-02-07  222.7261 1568.6000  10.1920 11.8290   382.4000 77.0446 144.4300
# 2020-02-08  223.1465       NaN      NaN     NaN        NaN     NaN      NaN
# ...              ...       ...      ...     ...        ...     ...      ...
# 2025-01-30 3247.7800 2823.0000   9.8452 20.3750   894.0000 54.3200  88.3400
# 2025-01-31 3298.2651 2812.5000   9.8508 20.4800   910.9000 54.6400  87.7600
# 2025-02-01 3118.3286       NaN      NaN     NaN        NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN      NaN     NaN        NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999   9.9112 20.1300   883.0000 54.4900  88.1600
#
# [1827 rows x 7 columns]

# %%
df.loc[:, ("Close", "ETH-USD")]
# Out:
# Date
# 2020-02-04    189.2506
# 2020-02-05    204.2302
# 2020-02-06    212.3391
# 2020-02-07    222.7261
# 2020-02-08    223.1465
#                 ...
# 2025-01-30   3247.7800
# 2025-01-31   3298.2651
# 2025-02-01   3118.3286
# 2025-02-02   2868.6929
# 2025-02-03   2884.5667
# Freq: D, Name: (Close, ETH-USD), Length: 1827, dtype: float64

# %%
close = df.Close.copy()
close
# Out:
#              ETH-USD      GC=F  GIST.SW  LCWD.L  LYTNOW.SW       O      TLT
# Date
# 2020-02-04  189.2506 1550.4000  10.1300 11.7240   374.3500 75.8915 143.5800
# 2020-02-05  204.2302 1557.8000  10.1360 11.8090   383.2500 76.0659 142.0100
# 2020-02-06  212.3391 1565.1000  10.1440 11.8700   380.5000 76.6957 142.6500
# 2020-02-07  222.7261 1568.6000  10.1920 11.8290   382.4000 77.0446 144.4300
# 2020-02-08  223.1465       NaN      NaN     NaN        NaN     NaN      NaN
# ...              ...       ...      ...     ...        ...     ...      ...
# 2025-01-30 3247.7800 2823.0000   9.8452 20.3750   894.0000 54.3200  88.3400
# 2025-01-31 3298.2651 2812.5000   9.8508 20.4800   910.9000 54.6400  87.7600
# 2025-02-01 3118.3286       NaN      NaN     NaN        NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN      NaN     NaN        NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999   9.9112 20.1300   883.0000 54.4900  88.1600
#
# [1827 rows x 7 columns]

# %%
close.describe()
# Out:
#         ETH-USD      GC=F   GIST.SW    LCWD.L  LYTNOW.SW         O       TLT
# count 1827.0000 1259.0000 1261.0000 1262.0000  1261.0000 1257.0000 1257.0000
# mean  2040.7095 1961.7350    9.9291   14.9005   585.1201   61.2208  121.9908
# std   1133.1393  281.7225    0.4037    2.5494   152.0145    6.5726   27.4574
# min    110.6059 1477.3000    9.1510    7.8800   260.5000   41.1822   82.7700
# 25%   1299.7055 1783.4500    9.6188   13.4085   476.9000   56.4700   96.0700
# 50%   1892.8621 1877.4000    9.9030   14.8310   554.4000   61.0000  113.7600
# 75%   2971.7462 2002.4000   10.3000   16.1118   649.2000   66.3900  148.0600
# max   4812.0874 2833.8999   10.9005   20.5000   945.8000   79.8837  171.5700

# %%
#close.dropna().plot(figsize = (15,8), fontsize = 13)
#plt.legend(fontsize = 13)
#plt.show()

# %% [markdown]
# ## Normalizing Financial Time Series to a Base Value (100)

# %%
# First Price 
close.iloc[0,0]
# Out:
# 189.25059509277344

# %%
close.div(close.iloc[0,0])
# Out:
#             ETH-USD    GC=F  GIST.SW  LCWD.L  LYTNOW.SW      O    TLT
# Date
# 2020-02-04   1.0000  8.1923   0.0535  0.0619     1.9781 0.4010 0.7587
# 2020-02-05   1.0792  8.2314   0.0536  0.0624     2.0251 0.4019 0.7504
# 2020-02-06   1.1220  8.2700   0.0536  0.0627     2.0106 0.4053 0.7538
# 2020-02-07   1.1769  8.2885   0.0539  0.0625     2.0206 0.4071 0.7632
# 2020-02-08   1.1791     NaN      NaN     NaN        NaN    NaN    NaN
# ...             ...     ...      ...     ...        ...    ...    ...
# 2025-01-30  17.1613 14.9167   0.0520  0.1077     4.7239 0.2870 0.4668
# 2025-01-31  17.4280 14.8612   0.0521  0.1082     4.8132 0.2887 0.4637
# 2025-02-01  16.4772     NaN      NaN     NaN        NaN    NaN    NaN
# 2025-02-02  15.1582     NaN      NaN     NaN        NaN    NaN    NaN
# 2025-02-03  15.2420 14.9743   0.0524  0.1064     4.6658 0.2879 0.4658
#
# [1827 rows x 7 columns]

# %%
# First Prices all tickers
close.iloc[0]
# Out:
# ETH-USD      189.2506
# GC=F        1550.4000
# GIST.SW       10.1300
# LCWD.L        11.7240
# LYTNOW.SW    374.3500
# O             75.8915
# TLT          143.5800
# Name: 2020-02-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#              ETH-USD     GC=F  GIST.SW   LCWD.L  LYTNOW.SW        O      TLT
# Date
# 2020-02-04  100.0000 100.0000 100.0000 100.0000   100.0000 100.0000 100.0000
# 2020-02-05  107.9152 100.4773 100.0592 100.7250   102.3775 100.2298  98.9065
# 2020-02-06  112.2000 100.9481 100.1382 101.2453   101.6428 101.0598  99.3523
# 2020-02-07  117.6884 101.1739 100.6120 100.8956   102.1504 101.5194 100.5920
# 2020-02-08  117.9106      NaN      NaN      NaN        NaN      NaN      NaN
# ...              ...      ...      ...      ...        ...      ...      ...
# 2025-01-30 1716.1267 182.0820  97.1885 173.7888   238.8139  71.5759  61.5267
# 2025-01-31 1742.8030 181.4048  97.2438 174.6844   243.3284  71.9975  61.1227
# 2025-02-01 1647.7246      NaN      NaN      NaN        NaN      NaN      NaN
# 2025-02-02 1515.8171      NaN      NaN      NaN        NaN      NaN      NaN
# 2025-02-03 1524.2048 182.7851  97.8401 171.6991   235.8755  71.7999  61.4013
#
# [1827 rows x 7 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close.to_csv("close.csv")
