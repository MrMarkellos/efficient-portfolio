# %% [markdown]
# # Libraries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Get historical Data using Yahoo Finance

# %%
start = "2020-02-04"
end = "2025-02-04"

# %%
tickers = [ "LCWD.L", "LYTNOW.SW", "ETH-USD", "TLT", "GIST.SW","GC=F", "O" ]

# %%
df = yf.download(tickers, start ,end)
df
# Out:
# [*********************100%***********************]  7 of 7 completed
# Price             Close                                                \
# Ticker          ETH-USD         GC=F   GIST.SW     LCWD.L   LYTNOW.SW
# Date
# 2020-02-04   189.250595  1550.400024  9.728142  11.724000  374.350006
# 2020-02-05   204.230240  1557.800049  9.733905  11.809000  383.250000
# 2020-02-06   212.339081  1565.099976  9.741587  11.870000  380.500000
# 2020-02-07   222.726059  1568.599976  9.787683  11.829000  382.399994
# 2020-02-08   223.146515          NaN       NaN        NaN         NaN
# ...                 ...          ...       ...        ...         ...
# 2025-01-30  3247.780029  2823.000000  9.845200  20.375000  894.000000
# 2025-01-31  3298.265137  2812.500000  9.850800  20.480000  910.900024
# 2025-02-01  3118.328613          NaN       NaN        NaN         NaN
# 2025-02-02  2868.692871          NaN       NaN        NaN         NaN
# 2025-02-03  2884.566650  2833.899902  9.911200  20.129999  883.000000
#
# Price                                     High                         ...  \
# Ticker              O         TLT      ETH-USD         GC=F   GIST.SW  ...
# Date                                                                   ...
# 2020-02-04  59.483841  126.123772   191.111496  1577.699951  9.728142  ...
# 2020-02-05  59.620548  124.744675   206.804001  1560.699951  9.733905  ...
# 2020-02-06  60.114231  125.306870   214.597717  1565.599976  9.741587  ...
# 2020-02-07  60.387627  126.870430   223.140930  1571.900024  9.787683  ...
# 2020-02-08        NaN         NaN   226.588089          NaN       NaN  ...
# ...               ...         ...          ...          ...       ...  ...
# 2025-01-30  54.057545   88.025932  3282.986328  2829.500000  9.845200  ...
# 2025-01-31  54.375999   87.447998  3437.569092  2838.000000  9.850800  ...
# 2025-02-01        NaN         NaN  3329.655273          NaN       NaN  ...
# 2025-02-02        NaN         NaN  3161.894287          NaN       NaN  ...
# 2025-02-03  54.490002   88.160004  2919.477295  2848.399902  9.911200  ...
#
# Price             Open                              Volume                   \
# Ticker       LYTNOW.SW          O         TLT      ETH-USD     GC=F GIST.SW
# Date
# 2020-02-04  374.350006  59.301561  126.483928  11714191695    978.0     0.0
# 2020-02-05  377.750000  59.149665  124.999425  14865434435   1305.0     0.0
# 2020-02-06  383.250000  59.711698  124.894010  16425589683    110.0     0.0
# 2020-02-07  382.399994  60.334465  126.685969  16673443564    431.0  2306.0
# 2020-02-08         NaN        NaN         NaN  16741203125      NaN     NaN
# ...                ...        ...         ...          ...      ...     ...
# 2025-01-30  906.299988  54.435710   88.095691  19958405782  40141.0     0.0
# 2025-01-31  910.900024  53.828658   88.065789  30128115902   3443.0     0.0
# 2025-02-01         NaN        NaN         NaN  19917507079      NaN     NaN
# 2025-02-02         NaN        NaN         NaN  42060930305      NaN     NaN
# 2025-02-03  875.400024  53.900002   88.580002  92453553253   2649.0     0.0
#
# Price
# Ticker        LCWD.L LYTNOW.SW          O         TLT
# Date
# 2020-02-04   12695.0     105.0  1291754.0  11388300.0
# 2020-02-05   32971.0     370.0  1843874.0  10782600.0
# 2020-02-06     888.0      28.0  1047686.0   6683100.0
# 2020-02-07    6196.0       1.0  1204034.0  11374800.0
# 2020-02-08       NaN       NaN        NaN         NaN
# ...              ...       ...        ...         ...
# 2025-01-30  138736.0      18.0  4277800.0  25094900.0
# 2025-01-31  462360.0      27.0  6777500.0  48812500.0
# 2025-02-01       NaN       NaN        NaN         NaN
# 2025-02-02       NaN       NaN        NaN         NaN
# 2025-02-03  237098.0     272.0  4324200.0  70657200.0
#
# [1827 rows x 35 columns]

# %%
df.to_csv("portfolio_data.csv")

# %% [markdown]
# ## Normalizing Financial Time Series to a Base Value (100)

# %%
df.Close
close = df.Close.copy()

# %%
# First Price 
close.iloc[0,0]
# Out:
# 189.25059509277344

# %%
close.div(close.iloc[0,0])
# Out:
# Ticker        ETH-USD       GC=F   GIST.SW    LCWD.L  LYTNOW.SW         O  \
# Date
# 2020-02-04   1.000000   8.192313  0.051403  0.061950   1.978065  0.314313
# 2020-02-05   1.079152   8.231414  0.051434  0.062399   2.025093  0.315035
# 2020-02-06   1.122000   8.269987  0.051475  0.062721   2.010562  0.317644
# 2020-02-07   1.176884   8.288481  0.051718  0.062504   2.020601  0.319088
# 2020-02-08   1.179106        NaN       NaN       NaN        NaN       NaN
# ...               ...        ...       ...       ...        ...       ...
# 2025-01-30  17.161267  14.916730  0.052022  0.107661   4.723895  0.285640
# 2025-01-31  17.428030  14.861248  0.052052  0.108216   4.813195  0.287323
# 2025-02-01  16.477246        NaN       NaN       NaN        NaN       NaN
# 2025-02-02  15.158171        NaN       NaN       NaN        NaN       NaN
# 2025-02-03  15.242048  14.974325  0.052371  0.106367   4.665771  0.287925
#
# Ticker           TLT
# Date
# 2020-02-04  0.666438
# 2020-02-05  0.659151
# 2020-02-06  0.662121
# 2020-02-07  0.670383
# 2020-02-08       NaN
# ...              ...
# 2025-01-30  0.465129
# 2025-01-31  0.462075
# 2025-02-01       NaN
# 2025-02-02       NaN
# 2025-02-03  0.465837
#
# [1827 rows x 7 columns]

# %%
# First Prices all tickers
close.iloc[0]
# Out:
# Ticker
# ETH-USD       189.250595
# GC=F         1550.400024
# GIST.SW         9.728142
# LCWD.L         11.724000
# LYTNOW.SW     374.350006
# O              59.483841
# TLT           126.123772
# Name: 2020-02-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker          ETH-USD        GC=F     GIST.SW      LCWD.L   LYTNOW.SW  \
# Date
# 2020-02-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2020-02-05   107.915243  100.477298  100.059241  100.725009  102.377453
# 2020-02-06   112.199954  100.948139  100.138206  101.245308  101.642846
# 2020-02-07   117.688433  101.173887  100.612046  100.895603  102.150391
# 2020-02-08   117.910601         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# 2025-01-30  1716.126720  182.082040  101.203290  173.788810  238.813940
# 2025-01-31  1742.803046  181.404796  101.260855  174.684404  243.328439
# 2025-02-01  1647.724601         NaN         NaN         NaN         NaN
# 2025-02-02  1515.817094         NaN         NaN         NaN         NaN
# 2025-02-03  1524.204798  182.785079  101.881734  171.699072  235.875514
#
# Ticker               O         TLT
# Date
# 2020-02-04  100.000000  100.000000
# 2020-02-05  100.229823   98.906553
# 2020-02-06  101.059767   99.352301
# 2020-02-07  101.519380  100.592004
# 2020-02-08         NaN         NaN
# ...                ...         ...
# 2025-01-30   90.877697   69.793292
# 2025-01-31   91.413060   69.335064
# 2025-02-01         NaN         NaN
# 2025-02-02         NaN         NaN
# 2025-02-03   91.604713   69.899593
#
# [1827 rows x 7 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close.to_csv("Daily_Prices.csv")

# %%
norm.to_csv("Daily_Prices_norm.csv")
