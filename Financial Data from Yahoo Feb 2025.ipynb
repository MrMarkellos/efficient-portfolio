# %% [markdown]
# # Libraries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Get historical Data using Yahoo Finance

# %%
start = "2020-02-04"
end = "2025-02-04"

# %%
tickers = [ "LCWD.L", "LYTNOW.SW", "ETH-USD", "TLT", "GIST.SW","GC=F", "O" ]

# %%
df = yf.download(tickers, start ,end)
df
# Out:
# [*********************100%***********************]  7 of 7 completed
# Price             Close                                                \
# Ticker          ETH-USD         GC=F   GIST.SW     LCWD.L   LYTNOW.SW
# Date
# 2020-02-04   189.250595  1550.400024  9.728143  11.724000  374.350006
# 2020-02-05   204.230240  1557.800049  9.733904  11.809000  383.250000
# 2020-02-06   212.339081  1565.099976  9.741586  11.870000  380.500000
# 2020-02-07   222.726059  1568.599976  9.787683  11.829000  382.399994
# 2020-02-08   223.146515          NaN       NaN        NaN         NaN
# ...                 ...          ...       ...        ...         ...
# 2025-01-30  3247.780029  2823.000000  9.845200  20.375000  894.000000
# 2025-01-31  3298.265137  2812.500000  9.850800  20.480000  910.900024
# 2025-02-01  3118.328613          NaN       NaN        NaN         NaN
# 2025-02-02  2868.692871          NaN       NaN        NaN         NaN
# ...

# %%
df.to_csv("portfolio_data.csv")

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
pd.read_csv ("portfolio_data.csv", header = [0,1], index_col = 0, parse_dates =[0])
# Out:
# Price          Close                                                       \
# Ticker       ETH-USD      GC=F GIST.SW  LCWD.L LYTNOW.SW       O      TLT
# Date
# 2020-02-04  189.2506 1550.4000  9.7281 11.7240  374.3500 59.4838 126.1237
# 2020-02-05  204.2302 1557.8000  9.7339 11.8090  383.2500 59.6205 124.7446
# 2020-02-06  212.3391 1565.1000  9.7416 11.8700  380.5000 60.1142 125.3068
# 2020-02-07  222.7261 1568.6000  9.7877 11.8290  382.4000 60.3876 126.8704
# 2020-02-08  223.1465       NaN     NaN     NaN       NaN     NaN      NaN
# ...              ...       ...     ...     ...       ...     ...      ...
# 2025-01-30 3247.7800 2823.0000  9.8452 20.3750  894.0000 54.0575  88.0259
# 2025-01-31 3298.2651 2812.5000  9.8508 20.4800  910.9000 54.3760  87.4480
# 2025-02-01 3118.3286       NaN     NaN     NaN       NaN     NaN      NaN
# 2025-02-02 2868.6929       NaN     NaN     NaN       NaN     NaN      NaN
# 2025-02-03 2884.5667 2833.8999  9.9112 20.1300  883.0000 54.4900  88.1600
#
# ...

# %% [markdown]
# ## Normalizing Financial Time Series to a Base Value (100)

# %%
df.Close
close = df.Close.copy()

# %%
# First Price 
close.iloc[0,0]
# Out:
# 189.25059509277344

# %%
close.div(close.iloc[0,0])
# Out:
# Ticker      ETH-USD    GC=F  GIST.SW  LCWD.L  LYTNOW.SW      O    TLT
# Date
# 2020-02-04   1.0000  8.1923   0.0514  0.0619     1.9781 0.3143 0.6664
# 2020-02-05   1.0792  8.2314   0.0514  0.0624     2.0251 0.3150 0.6592
# 2020-02-06   1.1220  8.2700   0.0515  0.0627     2.0106 0.3176 0.6621
# 2020-02-07   1.1769  8.2885   0.0517  0.0625     2.0206 0.3191 0.6704
# 2020-02-08   1.1791     NaN      NaN     NaN        NaN    NaN    NaN
# ...             ...     ...      ...     ...        ...    ...    ...
# 2025-01-30  17.1613 14.9167   0.0520  0.1077     4.7239 0.2856 0.4651
# 2025-01-31  17.4280 14.8612   0.0521  0.1082     4.8132 0.2873 0.4621
# 2025-02-01  16.4772     NaN      NaN     NaN        NaN    NaN    NaN
# 2025-02-02  15.1582     NaN      NaN     NaN        NaN    NaN    NaN
# 2025-02-03  15.2420 14.9743   0.0524  0.1064     4.6658 0.2879 0.4658
#
# [1827 rows x 7 columns]

# %%
# First Prices all tickers
close.iloc[0]
# Out:
# Ticker
# ETH-USD      189.2506
# GC=F        1550.4000
# GIST.SW        9.7281
# LCWD.L        11.7240
# LYTNOW.SW    374.3500
# O             59.4838
# TLT          126.1237
# Name: 2020-02-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker       ETH-USD     GC=F  GIST.SW   LCWD.L  LYTNOW.SW        O      TLT
# Date
# 2020-02-04  100.0000 100.0000 100.0000 100.0000   100.0000 100.0000 100.0000
# 2020-02-05  107.9152 100.4773 100.0592 100.7250   102.3775 100.2298  98.9065
# 2020-02-06  112.2000 100.9481 100.1382 101.2453   101.6428 101.0597  99.3523
# 2020-02-07  117.6884 101.1739 100.6120 100.8956   102.1504 101.5194 100.5920
# 2020-02-08  117.9106      NaN      NaN      NaN        NaN      NaN      NaN
# ...              ...      ...      ...      ...        ...      ...      ...
# 2025-01-30 1716.1267 182.0820 101.2033 173.7888   238.8139  90.8777  69.7933
# 2025-01-31 1742.8030 181.4048 101.2608 174.6844   243.3284  91.4131  69.3351
# 2025-02-01 1647.7246      NaN      NaN      NaN        NaN      NaN      NaN
# 2025-02-02 1515.8171      NaN      NaN      NaN        NaN      NaN      NaN
# 2025-02-03 1524.2048 182.7851 101.8817 171.6991   235.8755  91.6047  69.8996
#
# [1827 rows x 7 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close.to_csv("Daily_Prices.csv")

# %%
norm.to_csv("Daily_Prices_norm.csv")
