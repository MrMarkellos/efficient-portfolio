# %% [markdown]
# # Libraries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Get historical Data using Yahoo Finance

# %%
start = "2020-01-06"
end = "2025-01-06"

# %%
tickers = [ "CW8.MI", "LYTNOW.SW", "ETHE", "SXRC.MU", "IDTP.L","GC=F"]

# %%
df = yf.download(tickers, start ,end)
df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  6 of 6 completed
# Price            Close                                                  \
# Ticker          CW8.MI       ETHE         GC=F      IDTP.L   LYTNOW.SW
# Date
# 2020-01-06  312.010010   2.933333  1566.199951  220.850006  354.850006
# 2020-01-07  314.329987   3.194444  1571.800049  221.100006  356.500000
# 2020-01-08  315.170013   3.046667  1557.400024  220.600006  357.000000
# 2020-01-09  317.339996   2.977778  1551.699951  220.149994  363.200012
# 2020-01-10  317.230011   2.888889  1557.500000  221.000000  365.100006
# ...                ...        ...          ...         ...         ...
# 2024-12-27  571.869995  27.959999  2617.199951  238.210007  924.299988
# 2024-12-30  569.080017  28.450001  2606.100098  238.929993  921.000000
# 2024-12-31         NaN  28.020000  2629.199951  239.440002         NaN
# 2025-01-02  576.090027  28.920000  2658.899902  238.639999         NaN
# 2025-01-03  574.909973  30.219999  2645.000000  238.610001  918.500000
#
# Price                     High                                      ...  \
# Ticker     SXRC.MU      CW8.MI       ETHE         GC=F      IDTP.L  ...
# Date                                                                ...
# 2020-01-06  5.6300  312.480011   3.105556  1580.000000  222.270004  ...
# 2020-01-07  5.4100  314.480011   3.302222  1576.300049  222.199997  ...
# 2020-01-08  5.4400  315.019989   3.250000  1604.199951  221.270004  ...
# 2020-01-09  5.4400  317.700012   3.028889  1555.699951  220.600006  ...
# 2020-01-10  5.4400  318.380005   3.105556  1558.800049  221.139999  ...
# ...            ...         ...        ...          ...         ...  ...
# 2024-12-27  4.2460  576.440002  28.400000  2617.699951  238.720001  ...
# 2024-12-30  4.3060  571.890015  28.639999  2626.899902  240.110001  ...
# 2024-12-31     NaN         NaN  28.910000  2629.199951  240.500000  ...
# 2025-01-02  4.3190  576.090027  29.412001  2663.100098  239.619995  ...
# 2025-01-03  4.3015  575.000000  30.450001  2658.699951  240.119995  ...
#
# Price              Open                                   Volume             \
# Ticker             GC=F      IDTP.L   LYTNOW.SW SXRC.MU   CW8.MI       ETHE
# Date
# 2020-01-06  1580.000000  221.970001  350.799988  5.4500    655.0   113400.0
# 2020-01-07  1558.300049  222.199997  356.500000  5.4100     47.0   144900.0
# 2020-01-08  1579.699951  220.910004  357.000000  5.4400   1747.0   109800.0
# 2020-01-09  1555.699951  220.550003  361.450012  5.4400    112.0    78300.0
# 2020-01-10  1551.199951  220.690002  364.750000  5.4400    533.0   116100.0
# ...                 ...         ...         ...     ...      ...        ...
# 2024-12-27  2617.699951  238.279999  933.599976  4.2390   1931.0  2177700.0
# 2024-12-30  2620.699951  238.100006  926.000000  4.1800   4271.0  2748000.0
# 2024-12-31  2608.399902  240.500000         NaN     NaN      NaN  2276000.0
# 2025-01-02  2633.000000  238.309998         NaN  4.2845  14678.0  2946400.0
# 2025-01-03  2658.699951  240.119995  914.400024  4.3370   2177.0  2214000.0
#
# Price
# Ticker        GC=F   IDTP.L LYTNOW.SW  SXRC.MU
# Date
# 2020-01-06   416.0   2590.0    3279.0    122.0
# 2020-01-07    47.0  17509.0     150.0    122.0
# 2020-01-08   236.0   7182.0       0.0    122.0
# 2020-01-09    54.0   7986.0     393.0    122.0
# 2020-01-10    16.0  14958.0     249.0    122.0
# ...            ...      ...       ...      ...
# 2024-12-27   642.0  16084.0     284.0      0.0
# 2024-12-30   794.0   3859.0     240.0    110.0
# 2024-12-31   401.0   1630.0       NaN      NaN
# 2025-01-02  1728.0   9135.0       NaN  18000.0
# 2025-01-03   591.0   2610.0     950.0      0.0
#
# [1293 rows x 30 columns]

# %%
# Fill NaN values with the previous row values
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\marke\AppData\Local\Temp\ipykernel_21432\2674810900.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.to_csv("portfolio_data.csv")

# %% [markdown]
# ## Normalizing Financial Time Series to a Base Value (100)

# %%
df.Close
close = df.Close.copy()

# %%
# First Price 
close.iloc[0,0]
# Out:
# 312.010009765625

# %%
close.div(close.iloc[0,0])
# Out:
# Ticker        CW8.MI      ETHE      GC=F    IDTP.L  LYTNOW.SW   SXRC.MU
# Date
# 2020-01-06  1.000000  0.009401  5.019711  0.707830   1.137303  0.018044
# 2020-01-07  1.007436  0.010238  5.037659  0.708631   1.142592  0.017339
# 2020-01-08  1.010128  0.009765  4.991507  0.707029   1.144194  0.017435
# 2020-01-09  1.017083  0.009544  4.973238  0.705586   1.164065  0.017435
# 2020-01-10  1.016730  0.009259  4.991827  0.708311   1.170155  0.017435
# ...              ...       ...       ...       ...        ...       ...
# 2024-12-27  1.832858  0.089613  8.388192  0.763469   2.962405  0.013609
# 2024-12-30  1.823916  0.091183  8.352617  0.765777   2.951828  0.013801
# 2024-12-31  1.823916  0.089805  8.426653  0.767411   2.951828  0.013801
# 2025-01-02  1.846383  0.092689  8.521842  0.764847   2.951828  0.013843
# 2025-01-03  1.842601  0.096856  8.477292  0.764751   2.943816  0.013786
#
# [1293 rows x 6 columns]

# %%
# First Prices all tickers
close.iloc[0]
# Out:
# Ticker
# CW8.MI        312.010010
# ETHE            2.933333
# GC=F         1566.199951
# IDTP.L        220.850006
# LYTNOW.SW     354.850006
# SXRC.MU         5.630000
# Name: 2020-01-06 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker          CW8.MI         ETHE        GC=F      IDTP.L   LYTNOW.SW  \
# Date
# 2020-01-06  100.000000   100.000000  100.000000  100.000000  100.000000
# 2020-01-07  100.743558   108.901513  100.357560  100.113199  100.464983
# 2020-01-08  101.012789   103.863666   99.438135   99.886801  100.605888
# 2020-01-09  101.708274   101.515172   99.074192   99.683037  102.353109
# 2020-01-10  101.673024    98.484869   99.444518  100.067917  102.888544
# ...                ...          ...         ...         ...         ...
# 2024-12-27  183.285785   953.181921  167.105097  107.860539  260.476250
# 2024-12-30  182.391590   969.886526  166.396385  108.186546  259.546283
# 2024-12-31  182.391590   955.227423  167.871283  108.417476  259.546283
# 2025-01-02  184.638316   985.909232  169.767589  108.055238  259.546283
# 2025-01-03  184.260105  1030.227394  168.880097  108.041655  258.841760
#
# Ticker         SXRC.MU
# Date
# 2020-01-06  100.000000
# 2020-01-07   96.092358
# 2020-01-08   96.625221
# 2020-01-09   96.625221
# 2020-01-10   96.625221
# ...                ...
# 2024-12-27   75.417402
# 2024-12-30   76.483129
# 2024-12-31   76.483129
# 2025-01-02   76.714026
# 2025-01-03   76.403193
#
# [1293 rows x 6 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close.to_csv("Daily_Prices.csv")

# %%
norm.to_csv("Daily_Prices_norm.csv")
